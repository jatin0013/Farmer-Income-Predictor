# %%
import pandas as pd
data= pd.read_csv('LTF Challenge data with dictionary.csv')
print(data.head())
# Out:
#            FarmerID  ... Target_Variable/Total Income
# 0  1002818465057450  ...                      1360000
# 1  1012300674433870  ...                       807200
# 2  1013472263587380  ...                       500000
# 3  1019525480704050  ...                       558000
# 4  1021915867444260  ...                       800000
#
# [5 rows x 105 columns]

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#            FarmerID  ... Target_Variable/Total Income
# 0  1002818465057450  ...                      1360000
# 1  1012300674433870  ...                       807200
# 2  1013472263587380  ...                       500000
# 3  1019525480704050  ...                       558000
# 4  1021915867444260  ...                       800000
#
# [5 rows x 105 columns]

# %%
print(df.shape)
df.columns
# Out:
# (47970, 105)
# Index(['FarmerID', 'State', 'REGION', 'SEX', 'CITY', 'Zipcode', 'DISTRICT',
#        'VILLAGE', 'MARITAL_STATUS', 'Location',
#        ...
#        'Rabi Seasons Agro Ecological Sub Zone in 2020',
#        'Rabi Seasons Seasonal average groundwater thickness (cm) in 2020',
#        'Rabi Seasons Seasonal average groundwater replenishment rate (cm) in 2020',
#        ' Night light index',
#        ' Village score based on socio-economic parameters (Non normalised)',
#        ' Village score based on socio-economic parameters (0 to 100)',
#        ' Village category based on socio-economic parameters (Good, Average, Poor)',
#        ' Land Holding Index source (Total Agri Area/ no of people)',
#        ' Road density (Km/ SqKm)', 'Target_Variable/Total Income'],
#       dtype='object', length=105)

# %%
df.describe()
# Out:
#            FarmerID  ...  Target_Variable/Total Income
# count  4.797000e+04  ...                  4.797000e+04
# mean   5.488529e+15  ...                  1.222255e+06
# std    2.602973e+15  ...                  2.073935e+06
# min    1.000336e+15  ...                  2.900000e+04
# 25%    3.210170e+15  ...                  7.200000e+05
# 50%    5.488973e+15  ...                  9.500000e+05
# 75%    7.750388e+15  ...                  1.295000e+06
# max    9.999402e+15  ...                  8.000000e+07
#
# [8 rows x 67 columns]

# %%
num_cols = [col for col in df.columns if df[col].dtype !='object']
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
removed_cols = [col for col in num_cols  if df[col].std()<=0.2]
df.drop(columns=removed_cols,inplace=True)
removed_cols
# Out:
# [' Night light index']

# %%
df.shape
# Out:
# (47970, 104)

# %%
cat_cols
# Out:
# ['State',
#  'REGION',
#  'SEX',
#  'CITY',
#  'DISTRICT',
#  'VILLAGE',
#  'MARITAL_STATUS',
#  'Location',
#  'Address type',
#  'Ownership',
#  'K022-Village category based on Agri parameters (Good, Average, Poor)',
#  'K022-Nearest Mandi Name',
#  'K022-Village category based on socio-economic parameters (Good, Average, Poor)',
#  'K022-Ambient temperature (min & max)',
#  'R022-Village category based on Agri parameters (Good, Average, Poor)',
#  'R022-Ambient temperature (min & max)',
#  'K021-Ambient temperature (min & max)',
#  'R021-Ambient temperature (min & max)',
#  'R020-Ambient temperature (min & max)',
#  'Kharif Seasons  Type of soil in 2022',
#  'Kharif Seasons  Type of water bodies in hectares 2022',
#  'Kharif Seasons  Agro Ecological Sub Zone in 2022',
#  'Rabi Seasons Type of soil in 2022',
#  'Rabi Seasons Type of water bodies in hectares 2022',
#  'Rabi Seasons Agro Ecological Sub Zone in 2022',
#  'Rabi Seasons Type of soil in 2021',
# ...

# %%
'Target_Variable/Total Income' in df.columns
# Out:
# True

# %%
# from sklearn.preprocessing import LabelEncoder
# encoder = LabelEncoder()
# # for col in cat_cols:
# if 'SEX' in df.columns:
#     df['SEX_encoded'] = encoder.fit_transform(df['SEX'])
#     # df['SEX_encoded'] = encoder.fit_transform(df['SEX'])
# df = pd.get_dummies(df, columns=['State'], drop_first=True)

# for col in ['CITY', 'VILLAGE']:
#     freq_map = df[col].value_counts().to_dict()
#     df[f'{col}'] = df[col].map(freq_map)

# %%
'Target_Variable' in df.columns
# Out:
# False

# %%
pd.set_option('display.max_columns',None)
df.head()
# Out:
#            FarmerID           State   REGION SEX        CITY  Zipcode  \
# 0  1002818465057450  MADHYA PRADESH  CENTRAL   M      BARELI   464668
# 1  1012300674433870           BIHAR     EAST   M      BANDRA   848125
# 2  1013472263587380  MADHYA PRADESH  CENTRAL   M  MALHARGARH   458556
# 3  1019525480704050     MAHARASHTRA     WEST   M     RENAPUR   413527
# 4  1021915867444260  MADHYA PRADESH  CENTRAL   F      KHURAI   470117
#
#       DISTRICT   VILLAGE MARITAL_STATUS Location Address type Ownership  \
# 0       RAISEN     Seoni              M      NaN          NaN       NaN
# 1  MUZAFFARPUR   Namapur              M      NaN          NaN       NaN
# 2     MANDSAUR   Billaud              M      NaN          NaN       NaN
# 3        LATUR   Renapur              M      NaN          NaN       NaN
# 4        SAGAR  Singhpur              M      NaN          NaN       NaN
#
#    No_of_Active_Loan_In_Bureau  Avg_Disbursement_Amount_Bureau  \
# ...

# %%
num_cols = [col for col in df.columns if df[col].dtype !='object']
cat_cols = [col for col in df.columns if df[col].dtype == 'object']

# %%
cat_cols
# Out:
# ['State',
#  'REGION',
#  'SEX',
#  'CITY',
#  'DISTRICT',
#  'VILLAGE',
#  'MARITAL_STATUS',
#  'Location',
#  'Address type',
#  'Ownership',
#  'K022-Village category based on Agri parameters (Good, Average, Poor)',
#  'K022-Nearest Mandi Name',
#  'K022-Village category based on socio-economic parameters (Good, Average, Poor)',
#  'K022-Ambient temperature (min & max)',
#  'R022-Village category based on Agri parameters (Good, Average, Poor)',
#  'R022-Ambient temperature (min & max)',
#  'K021-Ambient temperature (min & max)',
#  'R021-Ambient temperature (min & max)',
#  'R020-Ambient temperature (min & max)',
#  'Kharif Seasons  Type of soil in 2022',
#  'Kharif Seasons  Type of water bodies in hectares 2022',
#  'Kharif Seasons  Agro Ecological Sub Zone in 2022',
#  'Rabi Seasons Type of soil in 2022',
#  'Rabi Seasons Type of water bodies in hectares 2022',
#  'Rabi Seasons Agro Ecological Sub Zone in 2022',
#  'Rabi Seasons Type of soil in 2021',
# ...

# %%
# cat_cols.remove['State']
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for col in cat_cols:
    df[col] = df[col].astype(str)  # ensure no NaNs
    df[col] = encoder.fit_transform(df[col])

# %%
df.dtypes
# Out:
# FarmerID                                                                        int64
# State                                                                           int32
# REGION                                                                          int32
# SEX                                                                             int32
# CITY                                                                            int32
#                                                                                ...
#  Village score based on socio-economic parameters (0 to 100)                  float64
#  Village category based on socio-economic parameters (Good, Average, Poor)      int32
#  Land Holding Index source (Total Agri Area/ no of people)                    float64
#  Road density (Km/ SqKm)                                                      float64
# Target_Variable/Total Income                                                    int64
# Length: 104, dtype: object

# %%
bool_cols = [col for col in df.columns if df[col].dtype=='bool']
bool_cols
# Out:
# []

# %%
df.drop(columns=bool_cols,inplace=True)

# %%
df.shape
# Out:
# (47970, 104)

# %%
df.columns
# Out:
# Index(['FarmerID', 'State', 'REGION', 'SEX', 'CITY', 'Zipcode', 'DISTRICT',
#        'VILLAGE', 'MARITAL_STATUS', 'Location',
#        ...
#        'Rabi Seasons Type of water bodies in hectares 2020',
#        'Rabi Seasons Agro Ecological Sub Zone in 2020',
#        'Rabi Seasons Seasonal average groundwater thickness (cm) in 2020',
#        'Rabi Seasons Seasonal average groundwater replenishment rate (cm) in 2020',
#        ' Village score based on socio-economic parameters (Non normalised)',
#        ' Village score based on socio-economic parameters (0 to 100)',
#        ' Village category based on socio-economic parameters (Good, Average, Poor)',
#        ' Land Holding Index source (Total Agri Area/ no of people)',
#        ' Road density (Km/ SqKm)', 'Target_Variable/Total Income'],
#       dtype='object', length=104)

# %%
df.head()
# Out:
#            FarmerID  State  REGION  SEX  CITY  Zipcode  DISTRICT  VILLAGE  \
# 0  1002818465057450      9       0    1   247   464668       308     4818
# 1  1012300674433870      2       1    1   211   848125       258     3857
# 2  1013472263587380      9       0    1  1541   458556       241     1046
# 3  1019525480704050     10       4    1  2195   413527       221     4567
# 4  1021915867444260      9       0    0  1312   470117       326     4944
#
#    MARITAL_STATUS  Location  Address type  Ownership  \
# 0               0     30634             3          3
# 1               0     30634             3          3
# 2               0     30634             3          3
# 3               0     30634             3          3
# 4               0     30634             3          3
#
#    No_of_Active_Loan_In_Bureau  Avg_Disbursement_Amount_Bureau  \
# 0                            0                             NaN
# 1                            1                    74000.000000
# ...

# %%
# getting difference of scores on year wise crop score
df['score_2022-21_rabi'] =df['Rabi Seasons Agricultural Score in 2022']-df['Rabi Seasons Agricultural Score in 2021']
df['score_2021-20_rabi'] =df['Rabi Seasons Agricultural Score in 2021']-df['Rabi Seasons Agricultural Score in 2020']
df['score_2022-21_kharif'] = df['Kharif Seasons Agricultural Score in 2021']-df['Kharif Seasons Agricultural Score in 2020']

# %%
# Perforing EDA on data 
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

sns.histplot(df['Target_Variable/Total Income'] , kde= 'True')
plt.title("Skewness of target variable")
plt.xlabel("Total Income")
plt.show()

# %% [markdown]
# * From above visuals we can see that our graph is Positively Skewed

# %%
# checking ditribution of farmer gender wise
plt.figure(figsize=(8,5))
sns.countplot(x='SEX', data=df , palette='dark')
plt.title("No of farmers according to sex" , fontweight = 'bold')
plt.xlabel("Sex M for male and F for female")
plt.ylabel("No of Farmers")
plt.legend()
plt.show()

# %% [markdown]
# * From above count plot we can see that the number of the Farmers who are male is greater than that of female

# %%
# checking ditribution of farmers accoridng to maritial status
plt.figure(figsize=(8,5))
sns.countplot(x='MARITAL_STATUS', data=df , palette='dark')
plt.title("No of farmers according to Marital status" , fontweight = 'bold')
plt.xlabel("Sex M for Married and S for sepearted and Nk for not known")
plt.ylabel("No of Farmers")
plt.legend()
plt.show()

# %% [markdown]
# * Mostly farmerS are Married

# %%
# checing the otliers according to sex
sns.boxplot(x='SEX' , y= 'Target_Variable/Total Income',data=df , palette='dark')
plt.title("Checking Outliers Of Income Coording to Gender" , fontweight ='bold')
plt.xlabel("Gender")
plt.ylabel("Total Income")
# Out:
# Text(0, 0.5, 'Total Income')

# %% [markdown]
# * From above visuals we can see that both sex either it is male or female both contains outliers in Income that they get

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='State', y ='Target_Variable/Total Income',data=df , palette= 'dark')
plt.xticks(rotation = 60)
plt.title("Target Income Distribution Across States" , fontweight='bold')
plt.xlabel("States",fontweight ='bold')
plt.ylabel("Income",fontweight ='bold')
plt.show()

# %% [markdown]
# * Top three states where income distribution are high are Rajasthan following Punjab following Haryana

# %%
# Getting feature selection by std 
import numpy as np

df['Log_Total_Land'] = np.log1p(df['Total_Land_For_Agriculture'])

# %%
feature_cols = [col for col in df.columns if df[col].std() <=0.2]
feature_cols
# Out:
# []

# %%
low_std_cols = df.select_dtypes(include=['int64', 'float64']).std()[df.std() < 0.2].index
# df.drop(columns=low_std_cols, inplace=True)

print(f"Dropped columns: {list(low_std_cols)}")
# Out:
# Dropped columns: []

# %%
df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('int32'), dtype('float64')], dtype=object)

# %%
import numpy as np 
# df.drop(['SCORE'],axis=1)
numeric_col = df.select_dtypes(include=['int64','int32','float64'])
corr_ =  numeric_col.corr()
print(corr_)
# Out:
#                               FarmerID     State    REGION       SEX  \
# FarmerID                      1.000000 -0.002058  0.002538  0.001727
# State                        -0.002058  1.000000  0.047918 -0.035339
# REGION                        0.002538  0.047918  1.000000 -0.115278
# SEX                           0.001727 -0.035339 -0.115278  1.000000
# CITY                          0.005626 -0.010047  0.041116 -0.004091
# ...                                ...       ...       ...       ...
# Target_Variable/Total Income  0.002190 -0.020548  0.009299 -0.018669
# score_2022-21_rabi           -0.003232  0.014955 -0.345008 -0.007952
# score_2021-20_rabi            0.006705  0.037634 -0.050388  0.013299
# score_2022-21_kharif         -0.000014  0.037427 -0.320869  0.024487
# Log_Total_Land               -0.002176 -0.080577  0.026127  0.053006
#
#                                   CITY   Zipcode  DISTRICT   VILLAGE  \
# ...

# %%
threshold = 0.1

# Select features with abs(correlation) >= threshold
strong_corr_features = corr_[corr_.abs() >= threshold].index.tolist()
print(strong_corr_features)
df_corr_selected = df [strong_corr_features]
# Out:
# ['FarmerID', 'State', 'REGION', 'SEX', 'CITY', 'Zipcode', 'DISTRICT', 'VILLAGE', 'MARITAL_STATUS', 'Location', 'Address type', 'Ownership', 'No_of_Active_Loan_In_Bureau', 'Avg_Disbursement_Amount_Bureau', 'Non_Agriculture_Income', 'Total_Land_For_Agriculture', 'K022-Village category based on Agri parameters (Good, Average, Poor)', 'K022-Nearest Mandi Name', 'K022-Proximity to nearest mandi (Km)', 'K022-Proximity to nearest railway (Km)', 'KO22-Village score based on socio-economic parameters (0 to 100)', 'K022-Village category based on socio-economic parameters (Good, Average, Poor)', 'K022-Seasonal Average Rainfall (mm)', 'K022-Ambient temperature (min & max)', 'R022-Village category based on Agri parameters (Good, Average, Poor)', 'R022-Seasonal Average Rainfall (mm)', 'R022-Ambient temperature (min & max)', 'K021-Seasonal Average Rainfall (mm)', 'K021-Ambient temperature (min & max)', 'R021-Seasonal Average Rainfall (mm)', 'R021-Ambient temperature (min & max)', 'R020-Seasonal Ave
# ...

# %%
df_corr_selected.shape
# Out:
# (47970, 108)

# %%
df.to_csv('new.csv')

# %%
df.shape
# Out:
# (47970, 108)

# %%
from sklearn.feature_selection import VarianceThreshold

# Remove features with very low variance
selector = VarianceThreshold(threshold=0.01)  # or 0.001 for finer filter
X_var = selector.fit_transform(df)
selected_columns = df.columns[selector.get_support()]

# %%
selected_columns.shape
# Out:
# (108,)

# %%
import seaborn as sns
import numpy as np

corr_matrix = df[selected_columns].corr().abs()
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Drop one of the two features with correlation > 0.9
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.9)]
X_reduced = df[selected_columns].drop(columns=to_drop)

# %%
X_reduced
# Out:
#                FarmerID  State  REGION  SEX  CITY  Zipcode  DISTRICT  VILLAGE  \
# 0      1002818465057450      9       0    1   247   464668       308     4818
# 1      1012300674433870      2       1    1   211   848125       258     3857
# 2      1013472263587380      9       0    1  1541   458556       241     1046
# 3      1019525480704050     10       4    1  2195   413527       221     4567
# 4      1021915867444260      9       0    0  1312   470117       326     4944
# ...                 ...    ...     ...  ...   ...      ...       ...      ...
# 47965  9674559574614020      8       3    1   961   573120       144      340
# 47966  3310239751166600      8       3    1    94   573130       144     3498
# 47967  3574921768222110      8       3    1   961   573120       144     4034
# 47968  2877092990946190      8       3    1    98   573162       144     4518
# 47969  1276738318694060      8       3    0   307   573125       144     3069
#
# ...

# %%
'Target_Variable/Total Income' in df.columns
# Out:
# True

# %%
X_train = X_reduced
Y_train = df['Target_Variable/Total Income']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(data=scaler.fit_transform(X_train),columns=X_train.columns)

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(X_train_scaled, Y_train, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_tr, y_tr)

importances = model.feature_importances_
feat_importance = pd.Series(importances, index=X_reduced.columns)
top_features = feat_importance.sort_values(ascending=False).head(40).index

# %%
X_final_tr = X_tr[top_features]
X_final_val = X_val[top_features]

# %%
X_final_tr
# Out:
#        Non_Agriculture_Income  Total_Land_For_Agriculture  DISTRICT   Zipcode  \
# 37177               -0.149681                   -0.717518  1.412381  0.709323
# 1478                -0.047686                   -0.427786  1.026205 -0.595099
# 43073                0.017188                   -1.007249  0.757561  2.871880
# 20506                0.127146                   -0.862383  1.412381  0.626234
# 34394               -0.117478                    0.006812  0.547683  0.136154
# ...                       ...                         ...       ...       ...
# 11284               -0.058928                    0.006812  1.513122 -0.187217
# 44732                0.134289                   -0.282920 -0.442942  2.230819
# 38158               -0.164319                         NaN  0.052370  0.285587
# 860                 -0.047218                    0.006812 -0.627635 -0.114285
# 15795                0.100037                   -0.862383 -0.031581  3.063211
#
# ...

# %%
X_final_val
# Out:
#        Non_Agriculture_Income  Total_Land_For_Agriculture  DISTRICT   Zipcode  \
# 853                 -0.047218                    0.006812  1.513122 -0.188157
# 15665               -0.164319                    0.876008 -0.149113 -2.951590
# 21609               -0.164319                    0.006812  0.925463 -0.003322
# 24632                0.245536                   -1.152115  0.119531 -2.873276
# 7687                -0.105768                    0.296544 -1.601469 -0.111448
# ...                       ...                         ...       ...       ...
# 5434                 0.101501                   -1.152115 -1.089367 -2.154692
# 26237               -0.047218                    0.006812 -0.988625 -0.133665
# 22734               -0.098449                   -0.717518 -0.451337  0.153722
# 13997               -0.105768                   -0.717518  0.262249 -0.235303
# 28974               -0.105768                    0.006812 -1.038996  0.754298
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100,random_state=42)
model.fit(X_final_tr,y_tr)

y_final_val_pred = model.predict(X_final_val)

# %%
from sklearn.metrics import r2_score,mean_absolute_percentage_error
print(mean_absolute_percentage_error(y_final_val_pred , y_val))
print(r2_score(y_final_val_pred,y_val))
# Out:
# 0.21062238501720518
# 0.9381831079861567

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100,random_state=42)
model.fit(X_train[top_features],Y_train)

# y_final_val_pred = model.predict(X_final_val)
# Out:
# RandomForestRegressor(random_state=42)

# %%
data = pd.read_excel("LTF Challenge data with dictionary.xlsx",sheet_name = "TestData")
data.to_csv('test_data.csv')

# %%
Test_data = pd.read_csv('test_data.csv')
Test_data.head()
# Out:
#    Unnamed: 0          FarmerID      State REGION SEX      CITY  Zipcode  \
# 0           0   576972022499073  KARNATAKA  SOUTH   M  TUMAKURU   572102
# 1           1   979235081831136    HARYANA  NORTH   M     KALKA   133302
# 2           2   176490610549774    HARYANA  NORTH   M   PINJORE   134102
# 3           3   977021407171384    HARYANA  NORTH   M   PINJORE   134102
# 4           4  1334154133262320    HARYANA  NORTH   M   PINJORE   134102
#
#     DISTRICT VILLAGE MARITAL_STATUS               Location       Address type  \
# 0     TUMKUR  Tumkur              M  13.3173175,77.1240408  Permanent Address
# 1  PANCHKULA   Kalka              M  30.4749107,77.1320795  Permanent Address
# 2  PANCHKULA   Kalka              M                    NaN                NaN
# 3  PANCHKULA   Kalka              S                    NaN                NaN
# 4  PANCHKULA   Kalka              M  30.7982131,76.9209035  Permanent Address
#
# ...

# %%
num_cols = [col for col in Test_data.columns if Test_data[col].dtype !='object']
cat_cols = [col for col in Test_data.columns if Test_data[col].dtype == 'object']

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for col in cat_cols:
    Test_data[col] = Test_data[col].astype(str)  # ensure no NaNs
    Test_data[col] = encoder.fit_transform(Test_data[col])

# %%
bool_cols = [col for col in Test_data.columns if Test_data[col].dtype=='bool']
bool_cols
df.drop(columns=bool_cols,inplace=True)

# %%
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold(threshold=0.01)  
X_var = selector.fit_transform(Test_data)
selected_columns = Test_data.columns[selector.get_support()]

# %%
Test_data['score_2022-21_rabi'] =Test_data['Rabi Seasons Agricultural Score in 2022']-Test_data['Rabi Seasons Agricultural Score in 2021']
Test_data['score_2021-20_rabi'] =Test_data['Rabi Seasons Agricultural Score in 2021']-Test_data['Rabi Seasons Agricultural Score in 2020']
Test_data['score_2022-21_kharif'] = Test_data['Kharif Seasons Agricultural Score in 2021']-Test_data['Kharif Seasons Agricultural Score in 2020']

# %%
X_test = Test_data[top_features]

# %%
y_final_test_pred = model.predict(X_test)

# %%
y_final_test_pred
# Out:
# array([1222549.6 , 1195359.17,  864732.  , ...,  745906.  , 1074534.  ,
#        1017622.  ])

# %%
output_df = pd.DataFrame({
    'ID': X_test['FarmerID'],          
    'Predicted_Income': y_final_test_pred
})
output_df.to_csv('farmer_income_predictions.csv', index=False)
output_df.to_excel('Final_result.xlsx',index = False)
